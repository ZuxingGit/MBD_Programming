# %%
# read data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000  \
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5  \
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
# leave only the columns we need
df = df[['date', 'Appliances']]
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
df.head()
# Out:
#                      Appliances
# date
# 2016-01-11 17:00:00          60
# 2016-01-11 17:10:00          60
# 2016-01-11 17:20:00          50
# 2016-01-11 17:30:00          50
# 2016-01-11 17:40:00          60

# %%
# leave data at hh:10:00 and hh:40:00
df = df[df.index.minute.isin([10, 40])]
df.head(10)
# Out:
#                      Appliances
# date
# 2016-01-11 17:10:00          60
# 2016-01-11 17:40:00          60
# 2016-01-11 18:10:00          60
# 2016-01-11 18:40:00         230
# 2016-01-11 19:10:00         250
# 2016-01-11 19:40:00          90
# 2016-01-11 20:10:00         140
# 2016-01-11 20:40:00         110
# 2016-01-11 21:10:00         110
# 2016-01-11 21:40:00         100

# %%
# take a sample data of one week
data_week = df['2016-02-01':'2016-02-07']
# take a sample data of 2 weeks
data_2weeks = df['2016-02-01':'2016-02-14']
# take a sample data of 4 weeks
data_4weeks = df['2016-02-01':'2016-02-28']

# %%
# use atuoarima to decide p,d,q
from pmdarima import auto_arima

# stepwise_model = auto_arima(data_4weeks, start_p=1, start_q=1,
#                            max_p=3, max_q=3, m=48,
#                            start_P=0, seasonal=True,
#                            d=1, D=1, trace=True,
#                            error_action='ignore',  
#                            suppress_warnings=True, 
#                            stepwise=True)

# %%
# use 2 weeks data
auto_arima(data_2weeks, start_p=1, start_q=1,
                max_p=3, max_q=3, m=48,
                start_P=0, seasonal=True,
                d=1, D=1, trace=True,
                error_action='ignore',  
                suppress_warnings=True, 
                stepwise=True)
# Out:
# Performing stepwise search to minimize aic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # use 2 weeks data
# ----> 2 auto_arima(data_2weeks, start_p=1, start_q=1,
#       3                 max_p=3, max_q=3, m=48,
#       4                 start_P=0, seasonal=True,
#       5                 d=1, D=1, trace=True,
#       6                 error_action='ignore',
#       7                 suppress_warnings=True,
#       8                 stepwise=True)
#
# ...

# %%
# use one week data
auto_arima(data_week, start_p=1, start_q=1,
                max_p=3, max_q=3, m=48,
                start_P=0, seasonal=True,
                d=1, D=1, trace=True,
                error_action='ignore',  
                suppress_warnings=True, 
                stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[48]             : AIC=inf, Time=17.54 sec
#  ARIMA(0,1,0)(0,1,0)[48]             : AIC=3739.462, Time=0.86 sec
#  ARIMA(1,1,0)(1,1,0)[48]             : AIC=3574.050, Time=2.83 sec
#  ARIMA(0,1,1)(0,1,1)[48]             : AIC=inf, Time=9.80 sec
#  ARIMA(1,1,0)(0,1,0)[48]             : AIC=3636.372, Time=0.45 sec
#  ARIMA(1,1,0)(2,1,0)[48]             : AIC=3560.028, Time=10.09 sec
#  ARIMA(1,1,0)(2,1,1)[48]             : AIC=inf, Time=27.77 sec
#  ARIMA(1,1,0)(1,1,1)[48]             : AIC=inf, Time=15.22 sec
#  ARIMA(0,1,0)(2,1,0)[48]             : AIC=3660.508, Time=7.35 sec
#  ARIMA(2,1,0)(2,1,0)[48]             : AIC=3547.555, Time=13.45 sec
#  ARIMA(2,1,0)(1,1,0)[48]             : AIC=3561.196, Time=3.79 sec
#  ARIMA(2,1,0)(2,1,1)[48]             : AIC=inf, Time=44.96 sec
#  ARIMA(2,1,0)(1,1,1)[48]             : AIC=inf, Time=21.30 sec
#  ARIMA(3,1,0)(2,1,0)[48]             : AIC=3525.919, Time=17.75 sec
# ...
